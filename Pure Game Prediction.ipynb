# %%
import numpy as np
from sklearn.linear_model import ElasticNet
from sklearn import model_selection
from sklearn.metrics import r2_score
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import urllib
from html_table_parser import HTMLTableParser
import requests
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler 
from sklearn.decomposition import PCA
from sklearn import linear_model as lm
from sklearn.metrics import accuracy_score

# %%
# Make Variables for all of the links to gamelogs
GSW06GL='https://www.basketball-reference.com/teams/GSW/2006/gamelog/'
CLE06GL='https://www.basketball-reference.com/teams/Cle/2006/gamelog/'
SAS06GL='https://www.basketball-reference.com/teams/SAS/2006/gamelog/'
BOS06GL='https://www.basketball-reference.com/teams/BOS/2006/gamelog/'
LAC06GL='https://www.basketball-reference.com/teams/LAC/2006/gamelog/'
TOR06GL='https://www.basketball-reference.com/teams/TOR/2006/gamelog/'
SEA06GL='https://www.basketball-reference.com/teams/SEA/2006/gamelog/'
NYK06GL='https://www.basketball-reference.com/teams/NYK/2006/gamelog/'
IND06GL='https://www.basketball-reference.com/teams/IND/2006/gamelog/'
MEM06GL='https://www.basketball-reference.com/teams/MEM/2006/gamelog/'
CHI06GL='https://www.basketball-reference.com/teams/CHI/2006/gamelog/'
UTA06GL='https://www.basketball-reference.com/teams/UTA/2006/gamelog/'
ATL06GL='https://www.basketball-reference.com/teams/ATL/2006/gamelog/'
MIN06GL='https://www.basketball-reference.com/teams/MIN/2006/gamelog/'
POR06GL='https://www.basketball-reference.com/teams/POR/2006/gamelog/'
DET06GL='https://www.basketball-reference.com/teams/DET/2006/gamelog/'
NOK06GL='https://www.basketball-reference.com/teams/NOK/2006/gamelog/'
WAS06GL='https://www.basketball-reference.com/teams/WAS/2006/gamelog/'
HOU06GL='https://www.basketball-reference.com/teams/HOU/2006/gamelog/'
MIA06GL='https://www.basketball-reference.com/teams/MIA/2006/gamelog/'
MIL06GL='https://www.basketball-reference.com/teams/MIL/2006/gamelog/'
ORL06GL='https://www.basketball-reference.com/teams/ORL/2006/gamelog/'
LAL06GL='https://www.basketball-reference.com/teams/LAL/2006/gamelog/'
DAL06GL='https://www.basketball-reference.com/teams/DAL/2006/gamelog/'
PHI06GL='https://www.basketball-reference.com/teams/PHI/2006/gamelog/'
SAC06GL='https://www.basketball-reference.com/teams/SAC/2006/gamelog/'
DEN06GL='https://www.basketball-reference.com/teams/DEN/2006/gamelog/'
CHA06GL='https://www.basketball-reference.com/teams/CHA/2006/gamelog/'
PHO06GL='https://www.basketball-reference.com/teams/PHO/2006/gamelog/'
NJN06GL='https://www.basketball-reference.com/teams/NJN/2006/gamelog/'
DFGL06url_list = ([ATL06GL, BOS06GL, CHA06GL,CHI06GL,CLE06GL,DAL06GL,DEN06GL,DET06GL,GSW06GL,HOU06GL,IND06GL, LAC06GL ,LAL06GL,MEM06GL, MIA06GL,MIL06GL,MIN06GL,NJN06GL,NOK06GL,NYK06GL,ORL06GL,PHI06GL,PHO06GL, POR06GL, SAC06GL,SAS06GL,SEA06GL,TOR06GL, UTA06GL,WAS06GL])

GSW07GL='https://www.basketball-reference.com/teams/GSW/2007/gamelog/'
# %%
#Convert all of the links to dataframes
# My computer is slow, so I have to do these in seperate commands

# %%
List0 = [pd.read_html(requests.get(x).content) for x in DFGL06url_list]

# %%
List1 = [pd.read_html(requests.get(x).content)for x in DFGL07url_list]

# %%
List2 = [pd.read_html(requests.get(x).content)for x in DFGL08url_list]

# %%
List3 = [pd.read_html(requests.get(x).content)for x in DFGL09url_list]

# %%
List4 = [pd.read_html(requests.get(x).content)for x in DFGL10url_list]

# %%
List5 = [pd.read_html(requests.get(x).content)for x in DFGL11url_list]

# %%
List6 = [pd.read_html(requests.get(x).content)for x in DFGL12url_list]

# %%
List7 = [pd.read_html(requests.get(x).content)for x in DFGL13url_list]

# %%
List8 = [pd.read_html(requests.get(x).content)for x in DFGL14url_list]

# %%
List9 = [pd.read_html(requests.get(x).content)for x in DFGL15url_list]

# %%
List10 = [pd.read_html(requests.get(x).content)for x in DFGL16url_list]

# %%
List11 = [pd.read_html(requests.get(x).content)for x in DFGL17url_list]

# %%
List12 = [pd.read_html(requests.get(x).content)for x in DFGL18url_list]

# %%
List13 = [pd.read_html(requests.get(x).content)for x in DFGL19url_list]

# %%
List14 = [pd.read_html(requests.get(x).content)for x in DFGL20url_list]

# %%
List15 = [pd.read_html(requests.get(x).content)for x in DFGL21url_list]

# %%
CurrentList = [pd.read_html(requests.get(x).content) for x in DFGL22url_list]

# %%
#Final step to Convert the lists to dataframes
Df06List = [x[-1] for x in List0]
Df07List = [x[-1] for x in List1]
Df08List = [x[-1] for x in List2]
Df09List = [x[-1] for x in List3]
Df10List = [x[-1] for x in List4]
Df11List = [x[-1] for x in List5]
Df12List = [x[-1] for x in List6]
Df13List = [x[-1] for x in List7]
Df14List = [x[-1] for x in List8]
Df15List = [x[-1] for x in List9]
Df16List = [x[-1] for x in List10]
Df17List = [x[-1] for x in List11]
Df18List = [x[-1] for x in List12]
Df19List = [x[-1] for x in List13]
Df20List = [x[-1] for x in List14]
Df21List = [x[-1] for x in List15]
CurrentL = [x[-1] for x in CurrentList]

# %%
#Make a list for ease of data running
DfGlList = ([Df06List,Df07List,Df08List,Df09List,Df10List,Df11List,Df12List,Df13List,Df14List,Df15List,Df16List,Df17List,Df18List,Df19List,Df20List,Df21List,CurrentL])

# %%
for x in DfGlList:
    for x in x:
        x.columns = ([ 'Rk', 'G','Date_y', 'Unnamed: 3_level_1', 'OppT', 'W/L', 'Tm', 'OppP', 'FG', 'FGA','FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'TRB', 'AST','STL', 'BLK', 'TOV', 'PF', 'Unnamed: 24_level_1', 'OppFG', 'OppFGA', 'OppFG%','Opp3P', 'Opp3PA', 'Opp3P%', 'OppFT', 'OppFTA', 'OppFT%', 'OppORB', 'OppTRB', 'OppAST', 'OppSTL','OppBLK', 'OppTOV', 'OppPF'])

#Drop the useless rows
#The first row is repeated throughout the dataframe

for season in DfGlList:
    for x in season:
        for i in range(len(x)):
            if x['OppFT'][i] == 'Opponent':
                    x.drop([i],inplace = True)
            elif x['Date_y'][i] == 'Date':
                    x.drop([i],inplace = True)
            

#Reset Dataframe of the dataframes
for x in DfGlList:
    for x in x:
        x.reset_index(drop = True,inplace = True)

# %%
#Dataframes came with 2 levels, drop the useless one
#NDFGL = [[x.droplevel(0,axis = 1) for x in x ]for x in DfGlList]
        

#There are repeats in the column names, change them to actually be able to run data

# %%
#columns are't in the correct form, need to be changed to float
#Conversion dictionary with each column that needs to be changed
conv_dict = {'Tm':float, 'OppP':float,'FG':float, 'FGA':float, 'FG%':float, '3P':float, '3PA':float, '3P%':float, 'FT':float, 'FTA':float, 'FT%':float, 'ORB':float,'TRB':float, 'AST':float, 'STL':float, 'BLK':float, 'TOV':float, 'PF':float, 'OppFGA':float, 'OppFG':float,'OppFG%':float, 'Opp3P':float,  'Opp3PA':float, 'Opp3P%':float, 'OppFT':float, 'OppFTA':float, 'OppFT%':float, 'OppORB':float, 'OppTRB':float, 'OppAST':float, 'OppSTL':float, 'OppBLK':float, 'OppTOV':float,'OppPF':float}
#convert to the correct type of data with line comprehension
NDFGL = [[x.astype(conv_dict) for x in x] for x in DfGlList]

# %%
#Margin of victory
for x in NDFGL:
    for x in x:
        x['Margin'] = x['Tm'] - x['OppP']

# %%
#Calculate advanced stats
for x in NDFGL:
    for x in x:
        x['BWL'] = np.where(x['Margin']>0, 1, 0)
        x['% from 3P'] = (3 * x['3P'])/(x['Tm'])
        x['% Opp 3'] = (3*x['Opp3P'])/(x['OppP'])
        x['% from FT'] = x['FT']/x['Tm']
        x['% Opp FT'] = x['OppFT']/x['OppP']
        x['Offensive Rating'] = (x['Tm']/(x['FGA']-x['ORB']+x['TOV']+(.4*x['FTA'])))*100
        x['Defensive Rating'] = (x['OppP']/(x['OppFGA']-x['OppORB']+x['OppTOV']+(.4*x['OppFTA'])))*100
        x['One Game Lag'] = x['BWL'].shift(1)
        x['Assist Ratio'] = (x['AST'] * 100) /(x['FG'] + (x['FTA'] * .44) + x['AST'] + x['TOV'])
        x['Opp Assist Ratio'] = (x['OppAST'] * 100)/(x['OppFG'] + (x['OppFTA'] * .44) + x['AST'] + x['TOV'])
        x['Opp Assisted Points'] = x['OppAST']/x['OppFG']
        x['5 Game Lag'] = x['BWL'].shift(1) + x['BWL'].shift(2) +x['BWL'].shift(3) +x['BWL'].shift(4) +x['BWL'].shift(5) 
        x['10 Game Lag'] = x['BWL'].shift(1) + x['BWL'].shift(2) +x['BWL'].shift(3) +x['BWL'].shift(4) +x['BWL'].shift(5) + x['BWL'].shift(6) + x['BWL'].shift(7) +x['BWL'].shift(8) +x['BWL'].shift(9) +x['BWL'].shift(10)
        x['ORB %'] = x['ORB']/(x['OppTRB']-x['OppORB'] + x['ORB'])
        x['Opp ORB %'] = x['OppORB'] / (x['TRB'] - x['ORB'] + x['OppORB'])
        x['DRB%'] = (x['TRB'] - x['ORB']) / (x['OppORB'] + x['TRB'] - x['ORB'])
        x['Opp DRB%'] = (x['OppTRB'] - x['OppORB']) / (x['ORB'] + x['OppTRB'] - x['OppORB'])
        x['A/T ratio'] = x['AST']/x['TOV']
        x['Opp A/T ratio'] = x['OppAST']/x['OppTOV']
        x['Effective FG %'] = x['FG'] + (.5 * x['3PA']) / x['FGA']
        x['True %'] = x['Tm']/ (2 * (x['FGA'] + (.44 * x['FTA'])))
        x['Opp Effective FG %'] = x['OppFG'] + ((.5 * x['Opp3PA'])/x['OppFGA'])
        x['Opp True %'] = x['OppP'] / (2 * (x['OppFGA'] + (.44 * x['OppFTA'])))

# %%
#Add a column of the means for each team
for x in NDFGL:
    for x in x:
        x['Mean OR'] = x['Offensive Rating'].mean()
        x['Mean DR'] = x['Defensive Rating'].mean()
        x['win %'] = x['BWL'].mean()
        x['Mean ORB %'] = x['ORB'].mean()
        x['Mean OppORB %'] = x['OppORB'].mean()
        x['Mean DRB%'] = x['DRB%'].mean()
        x['Mean Opp DRB%'] = x['Opp DRB%'].mean()
        x['Mean % from 3'] = x['% from 3P'].mean()
        x['Mean % from FT'] = x['% from FT'].mean()
        x['Mean % Opp 3'] = x['% Opp 3'].mean()
        x['Mean % Opp FT'] = x['% Opp FT'].mean()
        x['Mean Margin of Victory'] = x['Margin'].mean()
        x['Mean Assisted Ratio'] = x['Assist Ratio'].mean()
        x['Opp Mean Assist Ratio'] = x['Opp Assist Ratio'].mean()
        x['Mean A/T Ratio'] = x['A/T ratio'].mean()
        x['Mean Opp A/T Ratio'] = x['Opp A/T ratio'].mean()
        x['Mean Effective FG%'] = x['Effective FG %'].mean()
        x['Mean True %'] = x['True %'].mean()
        x['Mean Opp Effective FG%'] = x['Opp Effective FG %'].mean()
        x['Mean Opp True %'] = x['Opp True %'].mean()

# %%
for x in NDFGL:
    for x in x:
        x.drop([ 'W/L', 'Tm', 'OppP','FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'Unnamed: 24_level_1', 'OppFG', 'OppFGA', 'OppFG%', 'Opp3P', 'Opp3PA', 'Opp3P%', 'OppFT', 'OppFTA','OppFT%', 'OppORB', 'OppTRB', 'OppAST', 'OppSTL', 'OppBLK', 'OppTOV','OppPF', 'Margin',  '% Opp 3', '% from FT', '% Opp FT', 'Offensive Rating', 'Defensive Rating','Assist Ratio', 'Opp Assist Ratio', 'Opp Assisted Points','ORB %', 'Opp ORB %', 'DRB%', 'A/T ratio', 'Opp A/T ratio', 'Effective FG %', 'True %', 'Opp Effective FG %', 'Opp True %'], axis = 1, inplace = True)

# %%
List5 = [pd.concat(x,axis = 0) for x in NDFGL]

for x in List5:
    x.reset_index(drop = True, inplace=True)

#find the means
meanlists =[[x.describe() for x in x] for x in NDFGL]

#Drop useless columns
for x in meanlists:
    for x in x:
        x.drop(['One Game Lag','5 Game Lag', '10 Game Lag'], axis = 1 , inplace = True)

#Get just the means
mean = [[x.iloc[1:2,:] for x in x] for x in meanlists]
meanlist = [pd.concat(x) for x in mean]

# %%
listnames = []

for x in List5:
    listnames.append(x['OppT'])

listname = [x.sort_values() for x in listnames]

for x in listname:
    x.reset_index(drop = True, inplace = True)

# %%
names = [x.iloc[::int((len(x)/30)),] for x in listname]

for x in names:
    x.reset_index(drop = True, inplace = True)

#Reset Index
for x in meanlist:
    x.reset_index(drop = True, inplace = True)

oppmeans = []
df = []
def oppmean(a,b,c,d):
    x = pd.concat([a[c],b[c]],axis = 1)
    oppmeans.append(x)
    y = pd.merge(d[c],oppmeans[c], on = 'OppT')
    df.append(y)

# %%
currentSeason = pd.concat([meanlist[16],names[15]],axis = 1)

# %%
len(NDFGL)
# Out:
# 17

# %%
NDFGL = NDFGL[:16]
dfnum = [pd.concat(x) for x in NDFGL]

for i in range(len(dfnum)):
    oppmean(meanlist,names,i,dfnum)

for x in df:
    x.reset_index(drop = True, inplace = True)

for x in df:
    x.drop([], axis = 1, inplace = True)

# %%
len(df )
# Out:
# 16

# %%
df[0]
# Out:
#       Rk   G      Date_y Unnamed: 3_level_1 OppT  BWL_x  % from 3P_x  \
# 0      1   1  2005-11-02                  @  GSW      0     0.092784
# 1     59  59  2006-03-07                NaN  GSW      1     0.265487
# 2     24  24  2005-12-19                NaN  GSW      1     0.110092
# 3     27  27  2005-12-28                  @  GSW      0     0.110092
# 4     17  17  2005-12-02                  @  GSW      0     0.090000
# ...   ..  ..         ...                ...  ...    ...          ...
# 2455  65  65  2006-03-17                  @  ATL      1     0.216216
# 2456  33  33  2006-01-11                NaN  ATL      1     0.174757
# 2457  35  35  2006-01-14                  @  ATL      1     0.131579
# 2458  45  45  2006-02-04                NaN  ATL      1     0.122449
# 2459  75  75  2006-04-07                  @  ATL      0     0.326733
#
#       One Game Lag  5 Game Lag  10 Game Lag  ...  Mean % Opp FT_y  \
# 0              NaN         NaN          NaN  ...         0.196421
# ...

# %%
#Find the differential of the competing variables
for x in df:
    x['Win Percentage Differntial'] = ((x['win %_x'] - x['win %_y'])) 
    x['Offensive Rating Differential'] = x['Mean OR_x'] - x['Mean DR_y']
    x['Defensive Rating Differential'] = x['Mean DR_x'] - x['Mean OR_y']
    x['ORB Dif'] = x['Mean ORB %_x'] - x['Mean DRB%_y'] 
    x['Opp ORB Dif'] = x['Mean ORB %_y'] - x['Mean DRB%_x']
    x['% from 3P']= (x['Mean % from 3_x'] - x['Mean % Opp 3_y'] )  
    x['% from FT']= (x['Mean % from FT_x'] - x['Mean % Opp FT_y']) 
    x['Margin of Victory']= (x['Mean Margin of Victory_x'] - x['Mean Margin of Victory_y']) 
    x['Assist Ratio D'] = x['Mean Assisted Ratio_x'] - x['Opp Mean Assist Ratio_y']
    x['D Assist Ratio'] = x['Mean Assisted Ratio_y'] - x['Opp Mean Assist Ratio_x']
    x[' D % from 3P']= (x['Mean % from 3_y'] - x['Mean % Opp 3_x'] ) 
    x['D % from FT']= (x['Mean % from FT_y'] - x['Mean % Opp FT_x']) 
    x['A/T Ratio dif'] = x['Mean A/T Ratio_x'] - x['Mean Opp A/T Ratio_y']
    x['D A/T Ratio Dif'] = x['Mean A/T Ratio_y'] - x['Mean Opp A/T Ratio_x']

# %%
#Drop the columns that arent needed
for x in df:
    x.drop([ 'Opp DRB%_x', 'Mean OR_x', 'Mean DR_x',  'win %_x', 'Mean ORB %_x', 'Mean OppORB %_x', 'Mean DRB%_x','Mean Opp DRB%_x', 'Mean % from 3_x', 'Mean % from FT_x', 'Mean % Opp 3_x', 'Mean % Opp FT_x', 'Mean Margin of Victory_x', 'Mean Assisted Ratio_x', 'Opp Mean Assist Ratio_x', 'Mean A/T Ratio_x', 'Mean Opp A/T Ratio_x', 'Mean Effective FG%_x', 'Mean True %_x', 'Mean Opp Effective FG%_x', 'Mean Opp True %_x', 'Opp DRB%_y', 'Mean OR_y', 'Mean DR_y', 'win %_y', 'Mean ORB %_y', 'Mean OppORB %_y','Mean DRB%_y', 'Mean Opp DRB%_y', 'Mean % from 3_y', 'Mean % from FT_y', 'Mean % Opp 3_y', 'Mean % Opp FT_y', 'Mean Margin of Victory_y', 'Mean Assisted Ratio_y', 'Opp Mean Assist Ratio_y', 'Mean A/T Ratio_y',  'Mean Opp A/T Ratio_y', 'Mean Effective FG%_y', 'Mean True %_y', 'Mean Opp Effective FG%_y', 'Mean Opp True %_y'],axis = 1, inplace = True)

# %%
for x in df:
    x.drop('BWL_y',axis = 1,inplace = True)

# %%
#double check
for x in df:
    x.drop(['One Game Lag', '5 Game Lag', '10 Game Lag'],axis = 1, inplace = True)

# %%
#double check
for x in df:
    x.drop(['% from 3P_x','% from 3P_y'],axis =1 , inplace = True)

# %%
len(df)
# Out:
# 16

# %%
#Prep data for the pca
df = df[:16]
df3 = pd.concat(df)
print(df3.columns)
# Out:
# Index(['Rk', 'G', 'Date_y', 'Unnamed: 3_level_1', 'OppT', 'BWL_x',
#        'Win Percentage Differntial', 'Offensive Rating Differential',
#        'Defensive Rating Differential', 'ORB Dif', 'Opp ORB Dif', '% from 3P',
#        '% from FT', 'Margin of Victory', 'Assist Ratio D', 'D Assist Ratio',
#        ' D % from 3P', 'D % from FT', 'A/T Ratio dif', 'D A/T Ratio Dif'],
#       dtype='object')

# %%
df3.drop(['Rk', 'G', 'Date_y', 'Unnamed: 3_level_1', 'OppT'],axis =1,inplace = True)

# %%
df3.reset_index(drop = True, inplace = True)
df2 = df3.fillna(0)
#Wins or losses array
y = df2['BWL_x'].values
df2.drop(['BWL_x','Margin of Victory'],axis = 1,inplace = True)

# %%
#Prepare the x variables
independentMid= df2
independent = independentMid.fillna(0)

# %%
independent
# Out:
#        Win Percentage Differntial  Offensive Rating Differential  \
# 0                       -0.097561                       0.350233
# 1                       -0.097561                       0.350233
# 2                       -0.012195                      -0.822191
# 3                       -0.012195                      -0.822191
# 4                       -0.097561                      -4.111287
# ...                           ...                            ...
# 38402                    0.152778                       4.988600
# 38403                    0.152778                       4.988600
# 38404                   -0.097222                      -1.640970
# 38405                   -0.097222                      -1.640970
# 38406                   -0.097222                      -1.640970
#
#        Defensive Rating Differential    ORB Dif  Opp ORB Dif  % from 3P  \
# 0                           6.980528  12.316664    11.254285  -0.014246
# ...

# %%
import lightgbm
scale = StandardScaler()
scaled_data = scale.fit_transform(independent)
#run pca

model = PCA( n_components = 8 )
x = model.fit_transform(scaled_data)
X = x.astype(np.float32)

X_train, X_test, y_train, y_test = model_selection.train_test_split( X, y.ravel(), test_size = 0.25, random_state = 7 )

# %%
from sklearn.metrics import confusion_matrix

# Run a logistic regression on pure wins
model = lm.LogisticRegression()
model.fit(X_train,y_train)
#Predict the outcomes
predictions = model.predict(X_test)
x2 = model.predict(X_train)
#Accuracy Score of pure game picks
kfold = 10
print(accuracy_score(y_test,predictions))
print(accuracy_score(x2,y_train))
print( confusion_matrix( y_test, predictions ) )
results = model_selection.cross_val_score( model, X, y, cv = kfold )
print(results)
# Out:
# 0.6705894605290564
# 0.6661343516750564
# [[3154 1610]
#  [1553 3285]]
# [0.64618589 0.67456392 0.68523822 0.6904452  0.6206717  0.66336891
#  0.69955741 0.6609375  0.66953125 0.66041667]

# %%
#Naive Bayesean estimation

from sklearn.naive_bayes import GaussianNB 
import matplotlib.pyplot as plt 

from sklearn import model_selection 
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score
model = GaussianNB()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
predictions2 = model.predict(X_train)
print(accuracy_score(y_test,predictions))
print(accuracy_score(y_train,predictions2))
# Out:
# 0.6684024161632993
# 0.6679048776254123

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split( X, y.ravel(), test_size = 0.05, random_state = 7 )
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree._tree import TREE_LEAF
model = DecisionTreeClassifier( criterion = 'gini', min_samples_split = 30,max_depth = 15,min_samples_leaf = 30,max_leaf_nodes=200)
model.fit(X_train,y_train)
predictions = model.predict(X_test)
predictions2 = model.predict(X_train)
print(accuracy_score(y_test,predictions))
print(accuracy_score(y_train,predictions2))
# Out:
# 0.6663196251952108
# 0.685221728882311

# %%
from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test = model_selection.train_test_split( X, y.ravel(), test_size = 0.2, random_state = 7 )


model = KNeighborsClassifier( n_neighbors = 15, algorithm = 'kd_tree')
model.fit(X_train,y_train)
predictions = model.predict(X_test)
predictions2 = model.predict(X_train)
print(accuracy_score(y_test,predictions))
print(accuracy_score(y_train,predictions2))
# Out:
# 0.6375943764644624
# 0.6901871440195281

# %%
from xgboost import XGBClassifier

model = XGBClassifier(gamma = 18, max_depth = 3,min_child_weight = 0)
model.fit(X_train,y_train)
predictions = model.predict(X_test)
predictions2 = model.predict(X_train)
a = (accuracy_score(y_test, predictions))
b = accuracy_score(y_train,predictions2)
print(a)
print(b)
# Out:
# [10:53:04] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 0.6746940900807081
# 0.6694873881204231

# %%
#work on learning when teams average are showing in their statistics

# %%
params = {'gamma': range(10,25,1)}

# %%
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
gscv = GridSearchCV( estimator = XGBClassifier( max_depth = 3, gamma = 17,min_child_weight = 0), param_grid = params, n_jobs = 1, iid = False, cv = 5 )
gscv.fit( X_train, y_train.ravel() )
# Out:
# [10:53:07] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:53:08] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
print(gscv.best_params_)

# %%
#current season input

# %%
currentSeason = currentSeason.set_index(keys = 'OppT')

# %% [markdown]
# Must choose from these inputs

# %%
def matchups(team1,team2):
    t1 = currentSeason[team1:team1]
    t2 = currentSeason[team2:team2]
    t1 = t1.reset_index()
    t2 = t2.reset_index()
    statline = pd.concat([t1,t2],axis = 1)
    statline.columns = (['Team1','BWL_1', '% from 3P_1', 'Opp DRB%_1', 'Mean OR_1', 'Mean DR_1', 'win %_1',
       'Mean ORB %_1', 'Mean OppORB %_1', 'Mean DRB%_1', 'Mean Opp DRB%_1',
       'Mean % from 3_1', 'Mean % from FT_1', 'Mean % Opp 3_1', 'Mean % Opp FT_1',
       'Mean Margin of Victory_1', 'Mean Assisted Ratio_1',
       'Opp Mean Assist Ratio_1', 'Mean A/T Ratio_1', 'Mean Opp A/T Ratio_1',
       'Mean Effective FG%_1', 'Mean True %_1', 'Mean Opp Effective FG%_1',
       'Mean Opp True %_1', 'Rk_1', 'G_1', 'Team2','BWL_2', '% from 3P_2', 'Opp DRB%_2', 'Mean OR_2', 'Mean DR_2', 'win %_2',
       'Mean ORB %_2', 'Mean OppORB %_2', 'Mean DRB%_2', 'Mean Opp DRB%_2',
       'Mean % from 3_2', 'Mean % from FT_2', 'Mean % Opp 3_2', 'Mean % Opp FT_2',
       'Mean Margin of Victory_2', 'Mean Assisted Ratio_2',
       'Opp Mean Assist Ratio_2', 'Mean A/T Ratio_2', 'Mean Opp A/T Ratio_2',
       'Mean Effective FG%_2', 'Mean True %_2', 'Mean Opp Effective FG%_2',
       'Mean Opp True %_2', 'Rk_2', 'G_2'])
    statline['Win Percentage Differntial'] = ((statline['win %_1'] - statline['win %_2']))
    statline['Offensive Rating Differential'] = statline['Mean OR_1'] - statline['Mean DR_2']
    statline['Defensive Rating Differential'] = statline['Mean DR_1'] - statline['Mean OR_2']
    statline['ORB Dif'] = statline['Mean ORB %_2'] - statline['Mean DRB%_2'] 
    statline['Opp ORB Dif'] = statline['Mean ORB %_2'] - statline['Mean DRB%_1']
    statline['% from 3P']= (statline['Mean % from 3_1'] - statline['Mean % Opp 3_2'] ) 
    statline['% from FT']= (statline['Mean % from FT_1'] - statline['Mean % Opp FT_2'])
    statline['Margin of Victory dif']= (statline['Mean Margin of Victory_1'] - statline['Mean Margin of Victory_2']) 
    statline['Assist Ratio D'] = statline['Mean Assisted Ratio_1'] - statline['Opp Mean Assist Ratio_2']
    statline['D Assist Ratio'] = statline['Mean Assisted Ratio_2'] - statline['Opp Mean Assist Ratio_1']
    statline[' D % from 3P']= (statline['Mean % from 3_2'] - statline['Mean % Opp 3_1'] ) 
    statline['D % from FT']= (statline['Mean % from FT_2'] - statline['Mean % Opp FT_1']) 
    statline['A/T Ratio dif'] = statline['Mean A/T Ratio_1'] - statline['Mean Opp A/T Ratio_2']
    statline['D A/T Ratio Dif'] = statline['Mean A/T Ratio_2'] - statline['Mean Opp A/T Ratio_1']
    statline.drop(['Team1', 'Rk_1', 'G_1', 'BWL_1', '% from 3P_1', 'Opp DRB%_1',
       'Mean OR_1', 'Mean DR_1', 'win %_1', 'Mean ORB %_1', 'Mean OppORB %_1',
       'Mean DRB%_1', 'Mean Opp DRB%_1', 'Mean % from 3_1', 'Mean % from FT_1',
       'Mean % Opp 3_1', 'Mean % Opp FT_1', 'Mean Margin of Victory_1',
       'Mean Assisted Ratio_1', 'Opp Mean Assist Ratio_1', 'Mean A/T Ratio_1',
       'Mean Opp A/T Ratio_1', 'Mean Effective FG%_1', 'Mean True %_1',
       'Mean Opp Effective FG%_1', 'Mean Opp True %_1', 'Team2', 'Rk_2',
       'G_2', 'BWL_2', '% from 3P_2', 'Opp DRB%_2', 'Mean OR_2', 'Mean DR_2',
       'win %_2', 'Mean ORB %_2', 'Mean OppORB %_2', 'Mean DRB%_2',
       'Mean Opp DRB%_2', 'Mean % from 3_2', 'Mean % from FT_2',
       'Mean % Opp 3_2', 'Mean % Opp FT_2', 'Mean Margin of Victory_2',
       'Mean Assisted Ratio_2', 'Opp Mean Assist Ratio_2', 'Mean A/T Ratio_2',
       'Mean Opp A/T Ratio_2', 'Mean Effective FG%_2', 'Mean True %_2',
       'Mean Opp Effective FG%_2', 'Mean Opp True %_2','Margin of Victory dif'],axis = 1,inplace = True)
    df = pd.concat([df2,statline],axis = 0)
    df.reset_index(drop = True,inplace = True)
    return df

# %%
def currentScaleAndPCAPredict(data):
    scale = StandardScaler()
    scaled_data = scale.fit_transform(data)
    model =  PCA(n_components = 8)
    PCAdata = model.fit_transform(scaled_data)
    cut = PCAdata[len(PCAdata) - 1:]
    #model = XGBClassifier(gamma = 17, max_depth = 3,min_child_weight = 0)
    model = lm.LogisticRegression()
    model.fit(X_train,y_train)
    predictions = model.predict_proba(cut)[0]
    return predictions

# %%
def impliedMLDif(predictions,ML1,ML2,teams):
    #ML1 is the first team, ML2 is the second team
    if ML1 < 0:
        p1 = (-(ML1))/ (-(ML1) + 100)
    else:
        p1 = 100/(ML1 + 100)
    if ML2 < 0:
        p2 = (-(ML2))/ (-(ML2) + 100)
    else:
        p2 = 100/(ML2 + 100)
    difference1 = predictions[1] - p1
    difference2 = predictions[0] - p2
    if difference1 > difference2 and difference1> 0:
        return teams[0],difference1
    elif difference2 > difference1 and difference2 > 0:
        return teams[1],difference2
    else:
        print("do not bet on this game")

# %%
def prediction(teams,ML1,ML2):
    df = matchups(teams[0],teams[1])
    predictions = currentScaleAndPCAPredict(df)
    team = impliedMLDif(predictions,ML1,ML2,teams)
    return team

# %%
print(currentSeason.index)
# Out:
# Index(['ATL', 'BOS', 'BRK', 'CHI', 'CHO', 'CLE', 'DAL', 'DEN', 'DET', 'GSW',
#        'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NOP', 'NYK',
#        'OKC', 'ORL', 'PHI', 'PHO', 'POR', 'SAC', 'SAS', 'TOR', 'UTA', 'WAS'],
#       dtype='object', name='OppT')

# %%
teams = ['GSW','PHO']

# %%
prediction(teams,100,-100)
# Out:
# ('GSW', 0.004433488056038715)

# %%
w = np.array([.5,.5])
c = np.array([[.01,-.001],[-.001,.01]])
w.T@c@w
# Out:
# 0.0045000000000000005

# %%
w.T@c
# Out:
# array([0.0045, 0.0045])
